# %%
#importing the libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#ignore harmless errors

import warnings
warnings.filterwarnings("ignore")

#set to display all the columns in dataset

pd.set_option("display.max_columns",None)

#import psql to run queries

import pandasql as psql

# %%
#load the cancer data

Credit_Card_Data = pd.read_csv(r"C:\Users\Dlc\Videos\Project\clean_dataset.csv",header=0)

#copy to backup file

Credit_Card_copy = Credit_Card_Data.copy()

#Display first 5 records

Credit_Card_Data.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# 1       ByBirth       43     560         1
# 2       ByBirth      280     824         1
# 3       ByBirth      100       3         1
# 4  ByOtherMeans      120       0         1

# %%
#Display the information

Credit_Card_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    int64
#  9   Employed        690 non-null    int64
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    int64
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    int64
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    int64
# dtypes: float64(3), int64(10), object(3)
# memory usage: 86.4+ KB

# %%
#count the target or dependent variable by '0' & '1' and their proportion
# (>-10 : 1, then the dataset is instance data)

Approved_count = Credit_Card_Data.Approved.value_counts()
print('Class 0 : ', Approved_count[0])
print('Class 1: ',Approved_count[1])
print('Proportion : ',round(Approved_count[0] / Approved_count[1], 2),': 1' )
print('Total Bank records: ',len(Credit_Card_Data))
# Out:
# Class 0 :  383
# Class 1:  307
# Proportion :  1.25 : 1
# Total Bank records:  690

# %%
#Columns

Credit_Card_Data.columns
# Out:
# Index(['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'Industry',
#        'Ethnicity', 'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore',
#        'DriversLicense', 'Citizen', 'ZipCode', 'Income', 'Approved'],
#       dtype='object')

# %%
#Dropping columns

del_cols = ['Ethnicity','ZipCode']
Credit_Card_Data = Credit_Card_Data.drop(del_cols,axis=1)

# %%
#Display the data
Credit_Card_Data.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry  YearsEmployed  \
# 0       1  30.83  0.000        1             1  Industrials           1.25
# 1       0  58.67  4.460        1             1    Materials           3.04
# 2       0  24.50  0.500        1             1    Materials           1.50
# 3       1  27.83  1.540        1             1  Industrials           3.75
# 4       1  20.17  5.625        1             1  Industrials           1.71
#
#    PriorDefault  Employed  CreditScore  DriversLicense       Citizen  Income  \
# 0             1         1            1               0       ByBirth       0
# 1             1         1            6               0       ByBirth     560
# 2             1         0            0               0       ByBirth     824
# 3             1         1            5               1       ByBirth       3
# 4             1         0            0               0  ByOtherMeans       0
#
#    Approved
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
#Info
Credit_Card_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    object
#  6   YearsEmployed   690 non-null    float64
#  7   PriorDefault    690 non-null    int64
#  8   Employed        690 non-null    int64
#  9   CreditScore     690 non-null    int64
#  10  DriversLicense  690 non-null    int64
#  11  Citizen         690 non-null    object
#  12  Income          690 non-null    int64
#  13  Approved        690 non-null    int64
# dtypes: float64(3), int64(9), object(2)
# memory usage: 75.6+ KB

# %%
#use LabelEncoder to handle categorical data

from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

Credit_Card_Data['Industry'] = LE.fit_transform(Credit_Card_Data[['Industry']])
Credit_Card_Data['Citizen'] = LE.fit_transform(Credit_Card_Data[['Citizen']])

# %%
Credit_Card_Data['Approved'].value_counts()
# Out:
# 0    383
# 1    307
# Name: Approved, dtype: int64

# %%
#Counting out no of 1s and 0s
Credit_Card_Data['PriorDefault'].value_counts()
# Out:
# 1    361
# 0    329
# Name: PriorDefault, dtype: int64

# %%
#Counting out no of 1s and 0s
Credit_Card_Data['Employed'].value_counts()
# Out:
# 0    395
# 1    295
# Name: Employed, dtype: int64

# %%
#Counting out no of 1s and 0s
Credit_Card_Data['DriversLicense'].value_counts()
# Out:
# 0    374
# 1    316
# Name: DriversLicense, dtype: int64

# %%
#drop duplicates

#Displaying the duplicates
Credit_Card_Data_Dup = Credit_Card_Data[Credit_Card_Data.duplicated(keep='last')]

#Display the duplicate records
Credit_Card_Data_Dup
# Out:
# Empty DataFrame
# Columns: [Gender, Age, Debt, Married, BankCustomer, Industry, YearsEmployed, PriorDefault, Employed, CreditScore, DriversLicense, Citizen, Income, Approved]
# Index: []

# %%
#Info 

Credit_Card_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    int64
#  1   Age             690 non-null    float64
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    int64
#  4   BankCustomer    690 non-null    int64
#  5   Industry        690 non-null    int32
#  6   YearsEmployed   690 non-null    float64
#  7   PriorDefault    690 non-null    int64
#  8   Employed        690 non-null    int64
#  9   CreditScore     690 non-null    int64
#  10  DriversLicense  690 non-null    int64
#  11  Citizen         690 non-null    int32
#  12  Income          690 non-null    int64
#  13  Approved        690 non-null    int64
# dtypes: float64(3), int32(2), int64(9)
# memory usage: 70.2 KB

# %%
#null values

Credit_Card_Data.isnull().sum()
# Out:
# Gender            0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# Industry          0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# Income            0
# Approved          0
# dtype: int64

# %%
#Display

Credit_Card_Data.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer  Industry  YearsEmployed  \
# 0       1  30.83  0.000        1             1         7           1.25
# 1       0  58.67  4.460        1             1         9           3.04
# 2       0  24.50  0.500        1             1         9           1.50
# 3       1  27.83  1.540        1             1         7           3.75
# 4       1  20.17  5.625        1             1         7           1.71
#
#    PriorDefault  Employed  CreditScore  DriversLicense  Citizen  Income  \
# 0             1         1            1               0        0       0
# 1             1         1            6               0        0     560
# 2             1         0            0               0        0     824
# 3             1         1            5               1        0       3
# 4             1         0            0               0        1       0
#
#    Approved
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
#Columns

Credit_Card_Data.columns
# Out:
# Index(['Gender', 'Age', 'Debt', 'Married', 'BankCustomer', 'Industry',
#        'YearsEmployed', 'PriorDefault', 'Employed', 'CreditScore',
#        'DriversLicense', 'Citizen', 'Income', 'Approved'],
#       dtype='object')

# %%
Credit_Card_Data.shape
# Out:
# (690, 14)

# %%
#Identify the variables to normalize with minmaxscalar

cols = ['Age', 'Debt','Industry','YearsEmployed','CreditScore', 'Income']

# %%
#identify the independent and target (dependent) variables

Indepvar=[]
for col in Credit_Card_Data.columns:
    if col!='Approved':
        Indepvar.append(col)
targetvar='Approved'
x=Credit_Card_Data[Indepvar]
y=Credit_Card_Data[targetvar]

# %%
# Split the data into train and test (random sampling)

from sklearn.model_selection import train_test_split 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Display the shape for train & test data

x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((483, 13), (207, 13), (483,), (207,))

# %%
#Shape

Credit_Card_Data.shape
# Out:
# (690, 14)

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler=MinMaxScaler(feature_range=(0 , 1))

x_train[cols]=mmscaler.fit_transform(x_train[cols])
x_train=pd.DataFrame(x_train)

x_test[cols]=mmscaler.fit_transform(x_test[cols])
x_test=pd.DataFrame(x_test)

# %%
#Load the result for KNN

KNN_Results = pd.read_csv(r"C:\Users\Dlc\Videos\InternDocs\KNN_Results.csv",header=0)
 
KNN_Results.head()
# Out:
# Empty DataFrame
# Columns: [Model Name, KNN K Value, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %% [markdown]
# # KNN Algorithm

# %%
# Bild KNN Model

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

import sklearn.metrics as metrics

from sklearn.metrics import roc_curve, roc_auc_score

accuracy = []

for a in range(1, 21, 1):
    
    k = a
    
    # Build the model
    
    ModelKNN = KNeighborsClassifier(n_neighbors=k)
    
    # Train the model
    
    ModelKNN.fit(x_train, y_train)
    
    # Predict the model
    
    y_pred = ModelKNN.predict(x_test)
    y_pred_prob = ModelKNN.predict_proba(x_test)
    
    print('KNN_K_value = ', a)
    
    # Print the model name
    
    print('Model Name: ', ModelKNN)
    
    # confusion matrix in sklearn
    
    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report
    
    # actual values
    
    actual = y_test
    
    # predicted values
    
    predicted = y_pred
    
    # confusion matrix
    
    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)
    
    # outcome values order in sklearn
    
    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)
    
    # classification report for precision, recall f1-score and accuracy
    
    C_Report = classification_report(actual,predicted,labels=[1,0])
    
    print('Classification report : \n', C_Report)
    
    # calculating the metrics
    
    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);
    
    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model
    
    from math import sqrt
    
    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)
    
    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)
    
    # Area under ROC curve 
    
    from sklearn.metrics import roc_curve, roc_auc_score
    
    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    model_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, ModelKNN.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    #plt.savefig('Log_ROC')
    plt.show()
    #------------------------------------------------------------------------------
    new_row = {'Model Name' : ModelKNN,
               'KNN K Value' : a,
               'True_Positive' : tp,
               'False_Negative' : fn,
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    KNN_Results = KNN_Results.append(new_row, ignore_index=True)
    #------KNN_Results------------------------------------------------------------------------
# Out:
# KNN_K_value =  1
# Model Name:  KNeighborsClassifier(n_neighbors=1)
# Confusion matrix :
#  [[70 27]
#  [20 90]]
# Outcome values :
#  70 27 20 90
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.78      0.72      0.75        97
#            0       0.77      0.82      0.79       110
#
#     accuracy                           0.77       207
#    macro avg       0.77      0.77      0.77       207
# weighted avg       0.77      0.77      0.77       207
#
# Accuracy : 77.3 %
# Precision : 77.8 %
# Recall : 72.2 %
# F1 Score : 0.749
# Specificity or True Negative Rate : 81.8 %
# Balanced Accuracy : 77.0 %
# MCC : 0.543
# roc_auc_score: 0.77
# KNN_K_value =  2
# Model Name:  KNeighborsClassifier(n_neighbors=2)
# Confusion matrix :
#  [[ 65  32]
#  [  7 103]]
# Outcome values :
#  65 32 7 103
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.90      0.67      0.77        97
#            0       0.76      0.94      0.84       110
#
#     accuracy                           0.81       207
#    macro avg       0.83      0.80      0.81       207
# weighted avg       0.83      0.81      0.81       207
#
# Accuracy : 81.2 %
# Precision : 90.3 %
# Recall : 67.0 %
# F1 Score : 0.769
# Specificity or True Negative Rate : 93.6 %
# Balanced Accuracy : 80.3 %
# MCC : 0.635
# roc_auc_score: 0.803
# KNN_K_value =  3
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[83 14]
#  [12 98]]
# Outcome values :
#  83 14 12 98
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.87      0.86      0.86        97
#            0       0.88      0.89      0.88       110
#
#     accuracy                           0.87       207
#    macro avg       0.87      0.87      0.87       207
# weighted avg       0.87      0.87      0.87       207
#
# Accuracy : 87.4 %
# Precision : 87.4 %
# Recall : 85.6 %
# F1 Score : 0.865
# Specificity or True Negative Rate : 89.1 %
# Balanced Accuracy : 87.4 %
# MCC : 0.748
# roc_auc_score: 0.873
# KNN_K_value =  4
# Model Name:  KNeighborsClassifier(n_neighbors=4)
# Confusion matrix :
#  [[ 75  22]
#  [  8 102]]
# Outcome values :
#  75 22 8 102
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.90      0.77      0.83        97
#            0       0.82      0.93      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.85      0.85       207
# weighted avg       0.86      0.86      0.85       207
#
# Accuracy : 85.5 %
# Precision : 90.4 %
# Recall : 77.3 %
# F1 Score : 0.833
# Specificity or True Negative Rate : 92.7 %
# Balanced Accuracy : 85.0 %
# MCC : 0.713
# roc_auc_score: 0.85
# KNN_K_value =  5
# Model Name:  KNeighborsClassifier()
# Confusion matrix :
#  [[85 12]
#  [17 93]]
# Outcome values :
#  85 12 17 93
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.83      0.88      0.85        97
#            0       0.89      0.85      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 83.3 %
# Recall : 87.6 %
# F1 Score : 0.854
# Specificity or True Negative Rate : 84.5 %
# Balanced Accuracy : 86.0 %
# MCC : 0.72
# roc_auc_score: 0.861
# KNN_K_value =  6
# Model Name:  KNeighborsClassifier(n_neighbors=6)
# Confusion matrix :
#  [[80 17]
#  [13 97]]
# Outcome values :
#  80 17 13 97
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.86      0.82      0.84        97
#            0       0.85      0.88      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.85      0.85       207
# weighted avg       0.86      0.86      0.85       207
#
# Accuracy : 85.5 %
# Precision : 86.0 %
# Recall : 82.5 %
# F1 Score : 0.842
# Specificity or True Negative Rate : 88.2 %
# Balanced Accuracy : 85.3 %
# MCC : 0.709
# roc_auc_score: 0.853
# KNN_K_value =  7
# Model Name:  KNeighborsClassifier(n_neighbors=7)
# Confusion matrix :
#  [[82 15]
#  [14 96]]
# Outcome values :
#  82 15 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.85      0.85        97
#            0       0.86      0.87      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 85.4 %
# Recall : 84.5 %
# F1 Score : 0.85
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 85.9 %
# MCC : 0.719
# roc_auc_score: 0.859
# KNN_K_value =  8
# Model Name:  KNeighborsClassifier(n_neighbors=8)
# Confusion matrix :
#  [[81 16]
#  [13 97]]
# Outcome values :
#  81 16 13 97
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.86      0.84      0.85        97
#            0       0.86      0.88      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 86.2 %
# Recall : 83.5 %
# F1 Score : 0.848
# Specificity or True Negative Rate : 88.2 %
# Balanced Accuracy : 85.8 %
# MCC : 0.718
# roc_auc_score: 0.858
# KNN_K_value =  9
# Model Name:  KNeighborsClassifier(n_neighbors=9)
# Confusion matrix :
#  [[82 15]
#  [14 96]]
# Outcome values :
#  82 15 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.85      0.85        97
#            0       0.86      0.87      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 85.4 %
# Recall : 84.5 %
# F1 Score : 0.85
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 85.9 %
# MCC : 0.719
# roc_auc_score: 0.859
# KNN_K_value =  10
# Model Name:  KNeighborsClassifier(n_neighbors=10)
# Confusion matrix :
#  [[80 17]
#  [14 96]]
# Outcome values :
#  80 17 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.82      0.84        97
#            0       0.85      0.87      0.86       110
#
#     accuracy                           0.85       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.85      0.85      0.85       207
#
# Accuracy : 85.0 %
# Precision : 85.1 %
# Recall : 82.5 %
# F1 Score : 0.838
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 84.9 %
# MCC : 0.699
# roc_auc_score: 0.849
# KNN_K_value =  11
# Model Name:  KNeighborsClassifier(n_neighbors=11)
# Confusion matrix :
#  [[83 14]
#  [15 95]]
# Outcome values :
#  83 14 15 95
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85        97
#            0       0.87      0.86      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 84.7 %
# Recall : 85.6 %
# F1 Score : 0.851
# Specificity or True Negative Rate : 86.4 %
# Balanced Accuracy : 86.0 %
# MCC : 0.719
# roc_auc_score: 0.86
# KNN_K_value =  12
# Model Name:  KNeighborsClassifier(n_neighbors=12)
# Confusion matrix :
#  [[81 16]
#  [14 96]]
# Outcome values :
#  81 16 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.84      0.84        97
#            0       0.86      0.87      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.86      0.86      0.85       207
#
# Accuracy : 85.5 %
# Precision : 85.3 %
# Recall : 83.5 %
# F1 Score : 0.844
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 85.4 %
# MCC : 0.709
# roc_auc_score: 0.854
# KNN_K_value =  13
# Model Name:  KNeighborsClassifier(n_neighbors=13)
# Confusion matrix :
#  [[83 14]
#  [16 94]]
# Outcome values :
#  83 14 16 94
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.84      0.86      0.85        97
#            0       0.87      0.85      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.86      0.85       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 85.5 %
# Precision : 83.8 %
# Recall : 85.6 %
# F1 Score : 0.847
# Specificity or True Negative Rate : 85.5 %
# Balanced Accuracy : 85.5 %
# MCC : 0.709
# roc_auc_score: 0.855
# KNN_K_value =  14
# Model Name:  KNeighborsClassifier(n_neighbors=14)
# Confusion matrix :
#  [[83 14]
#  [16 94]]
# Outcome values :
#  83 14 16 94
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.84      0.86      0.85        97
#            0       0.87      0.85      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.86      0.85       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 85.5 %
# Precision : 83.8 %
# Recall : 85.6 %
# F1 Score : 0.847
# Specificity or True Negative Rate : 85.5 %
# Balanced Accuracy : 85.5 %
# MCC : 0.709
# roc_auc_score: 0.855
# KNN_K_value =  15
# Model Name:  KNeighborsClassifier(n_neighbors=15)
# Confusion matrix :
#  [[83 14]
#  [16 94]]
# Outcome values :
#  83 14 16 94
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.84      0.86      0.85        97
#            0       0.87      0.85      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.86      0.85       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 85.5 %
# Precision : 83.8 %
# Recall : 85.6 %
# F1 Score : 0.847
# Specificity or True Negative Rate : 85.5 %
# Balanced Accuracy : 85.5 %
# MCC : 0.709
# roc_auc_score: 0.855
# KNN_K_value =  16
# Model Name:  KNeighborsClassifier(n_neighbors=16)
# Confusion matrix :
#  [[83 14]
#  [15 95]]
# Outcome values :
#  83 14 15 95
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85        97
#            0       0.87      0.86      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 84.7 %
# Recall : 85.6 %
# F1 Score : 0.851
# Specificity or True Negative Rate : 86.4 %
# Balanced Accuracy : 86.0 %
# MCC : 0.719
# roc_auc_score: 0.86
# KNN_K_value =  17
# Model Name:  KNeighborsClassifier(n_neighbors=17)
# Confusion matrix :
#  [[83 14]
#  [15 95]]
# Outcome values :
#  83 14 15 95
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85        97
#            0       0.87      0.86      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 84.7 %
# Recall : 85.6 %
# F1 Score : 0.851
# Specificity or True Negative Rate : 86.4 %
# Balanced Accuracy : 86.0 %
# MCC : 0.719
# roc_auc_score: 0.86
# KNN_K_value =  18
# Model Name:  KNeighborsClassifier(n_neighbors=18)
# Confusion matrix :
#  [[83 14]
#  [14 96]]
# Outcome values :
#  83 14 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.86      0.86      0.86        97
#            0       0.87      0.87      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.5 %
# Precision : 85.6 %
# Recall : 85.6 %
# F1 Score : 0.856
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 86.4 %
# MCC : 0.728
# roc_auc_score: 0.864
# KNN_K_value =  19
# Model Name:  KNeighborsClassifier(n_neighbors=19)
# Confusion matrix :
#  [[83 14]
#  [15 95]]
# Outcome values :
#  83 14 15 95
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.86      0.85        97
#            0       0.87      0.86      0.87       110
#
#     accuracy                           0.86       207
#    macro avg       0.86      0.86      0.86       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 86.0 %
# Precision : 84.7 %
# Recall : 85.6 %
# F1 Score : 0.851
# Specificity or True Negative Rate : 86.4 %
# Balanced Accuracy : 86.0 %
# MCC : 0.719
# roc_auc_score: 0.86
# KNN_K_value =  20
# Model Name:  KNeighborsClassifier(n_neighbors=20)
# Confusion matrix :
#  [[81 16]
#  [14 96]]
# Outcome values :
#  81 16 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.84      0.84        97
#            0       0.86      0.87      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.86      0.86      0.85       207
#
# Accuracy : 85.5 %
# Precision : 85.3 %
# Recall : 83.5 %
# F1 Score : 0.844
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 85.4 %
# MCC : 0.709
# roc_auc_score: 0.854

# %%
#Display KNN Results

KNN_Results
# Out:
#                               Model Name KNN K Value True_Positive  \
# 0    KNeighborsClassifier(n_neighbors=1)           1            70
# 1    KNeighborsClassifier(n_neighbors=2)           2            65
# 2    KNeighborsClassifier(n_neighbors=3)           3            83
# 3    KNeighborsClassifier(n_neighbors=4)           4            75
# 4                 KNeighborsClassifier()           5            85
# 5    KNeighborsClassifier(n_neighbors=6)           6            80
# 6    KNeighborsClassifier(n_neighbors=7)           7            82
# 7    KNeighborsClassifier(n_neighbors=8)           8            81
# 8    KNeighborsClassifier(n_neighbors=9)           9            82
# 9   KNeighborsClassifier(n_neighbors=10)          10            80
# 10  KNeighborsClassifier(n_neighbors=11)          11            83
# 11  KNeighborsClassifier(n_neighbors=12)          12            81
# 12  KNeighborsClassifier(n_neighbors=13)          13            83
# 13  KNeighborsClassifier(n_neighbors=14)          14            83
# 14  KNeighborsClassifier(n_neighbors=15)          15            83
# 15  KNeighborsClassifier(n_neighbors=16)          16            83
# 16  KNeighborsClassifier(n_neighbors=17)          17            83
# 17  KNeighborsClassifier(n_neighbors=18)          18            83
# 18  KNeighborsClassifier(n_neighbors=19)          19            83
# 19  KNeighborsClassifier(n_neighbors=20)          20            81
#
#    False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0              27             20            90     0.773      0.778   0.722
# 1              32              7           103     0.812      0.903   0.670
# 2              14             12            98     0.874      0.874   0.856
# 3              22              8           102     0.855      0.904   0.773
# 4              12             17            93     0.860      0.833   0.876
# 5              17             13            97     0.855      0.860   0.825
# 6              15             14            96     0.860      0.854   0.845
# 7              16             13            97     0.860      0.862   0.835
# 8              15             14            96     0.860      0.854   0.845
# 9              17             14            96     0.850      0.851   0.825
# 10             14             15            95     0.860      0.847   0.856
# 11             16             14            96     0.855      0.853   0.835
# 12             14             16            94     0.855      0.838   0.856
# 13             14             16            94     0.855      0.838   0.856
# 14             14             16            94     0.855      0.838   0.856
# 15             14             15            95     0.860      0.847   0.856
# 16             14             15            95     0.860      0.847   0.856
# 17             14             14            96     0.865      0.856   0.856
# 18             14             15            95     0.860      0.847   0.856
# 19             16             14            96     0.855      0.853   0.835
#
#     F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0      0.749        0.818  0.543       0.769916              0.770
# 1      0.769        0.936  0.635       0.803233              0.803
# 2      0.865        0.891  0.748       0.873290              0.874
# 3      0.833        0.927  0.713       0.850234              0.850
# 4      0.854        0.845  0.720       0.860872              0.860
# 5      0.842        0.882  0.709       0.853280              0.853
# 6      0.850        0.873  0.719       0.859044              0.859
# 7      0.848        0.882  0.718       0.858435              0.858
# 8      0.850        0.873  0.719       0.859044              0.859
# 9      0.838        0.873  0.699       0.848735              0.849
# 10     0.851        0.864  0.719       0.859653              0.860
# 11     0.844        0.873  0.709       0.853889              0.854
# 12     0.847        0.855  0.709       0.855108              0.855
# 13     0.847        0.855  0.709       0.855108              0.855
# 14     0.847        0.855  0.709       0.855108              0.855
# 15     0.851        0.864  0.719       0.859653              0.860
# 16     0.851        0.864  0.719       0.859653              0.860
# 17     0.856        0.873  0.728       0.864199              0.864
# 18     0.851        0.864  0.719       0.859653              0.860
# 19     0.844        0.873  0.709       0.853889              0.854

# %% [markdown]
# # SVM Algorithm

# %%
#Loading out empty file

EMResults1 = pd.read_csv(r"C:\Users\Dlc\Videos\InternDocs\EMResults.csv",header=0)

# %%
#SVM-linear
# Training the SVM algorithm with train dataset

from sklearn.svm import SVC

ModelSVM1 = SVC(C=1.0, kernel='linear', degree=3, gamma='scale', coef0=0.0, shrinking=True, 
                probability=True, tol=0.001, cache_size=200, class_weight=None, verbose=False, 
                max_iter=- 1, decision_function_shape='ovr', break_ties=False, random_state=None)

# Train the model with train data 

ModelSVM1 = ModelSVM1.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVM1.predict(x_test)
y_pred_prob = ModelSVM1.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Linear")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
model_roc_auc = roc_auc_score(actual, predicted)
fpr, tpr, thresholds = roc_curve(actual,ModelSVM1.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot(fpr, tpr, label= 'Classification Model' % model_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---

new_row = {'Model Name' : "SVM - Linear",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults1 = EMResults1.append(new_row, ignore_index=True)
#-------------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Linear
# Confusion matrix :
#  [[89  8]
#  [25 85]]
# Outcome values :
#  89 8 25 85
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.78      0.92      0.84        97
#            0       0.91      0.77      0.84       110
#
#     accuracy                           0.84       207
#    macro avg       0.85      0.85      0.84       207
# weighted avg       0.85      0.84      0.84       207
#
# Accuracy : 84.1 %
# Precision : 78.1 %
# Recall : 91.8 %
# F1 Score : 0.844
# Specificity or True Negative Rate : 77.3 %
# Balanced Accuracy : 84.6 %
# MCC : 0.692
# roc_auc_score: 0.845
# -----------------------------------------------------------------------------------------------------

# %%
#SVM-poly

# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMPoly = SVC(kernel='poly', degree=2, probability=True)

# Train the model

ModelSVMPoly.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMPoly.predict(x_test)
y_pred_prob = ModelSVMPoly.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Polynominal")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMPoly.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---

new_row = {'Model Name' : "SVM - Polynominal",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults1 = EMResults1.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Polynominal
# Confusion matrix :
#  [[85 12]
#  [20 90]]
# Outcome values :
#  85 12 20 90
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.81      0.88      0.84        97
#            0       0.88      0.82      0.85       110
#
#     accuracy                           0.85       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.85      0.85      0.85       207
#
# Accuracy : 84.5 %
# Precision : 81.0 %
# Recall : 87.6 %
# F1 Score : 0.842
# Specificity or True Negative Rate : 81.8 %
# Balanced Accuracy : 84.7 %
# MCC : 0.693
# roc_auc_score: 0.847
# -----------------------------------------------------------------------------------------------------

# %%
#SVM-rbf

# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMGaussian = SVC(kernel='rbf', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMGaussian.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMGaussian.predict(x_test)
y_pred_prob = ModelSVMGaussian.predict_proba(x_test)

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# Print the model name
    
print('Model Name: ', "SVM - Gaussian")

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMGaussian.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---
new_row = {'Model Name' : "SVM - Gaussian",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults1 = EMResults1.append(new_row, ignore_index=True)
#---------------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Gaussian
# Confusion matrix :
#  [[88  9]
#  [25 85]]
# Outcome values :
#  88 9 25 85
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.78      0.91      0.84        97
#            0       0.90      0.77      0.83       110
#
#     accuracy                           0.84       207
#    macro avg       0.84      0.84      0.84       207
# weighted avg       0.85      0.84      0.84       207
#
# Accuracy : 83.6 %
# Precision : 77.9 %
# Recall : 90.7 %
# F1 Score : 0.838
# Specificity or True Negative Rate : 77.3 %
# Balanced Accuracy : 84.0 %
# MCC : 0.681
# roc_auc_score: 0.84
# -----------------------------------------------------------------------------------------------------

# %%
#SVM-sigmoid


# Training the SVM algorithm

from sklearn.svm import SVC

ModelSVMSig = SVC(kernel='sigmoid', random_state = 42, class_weight='balanced', probability=True)

# Train the model

ModelSVMSig.fit(x_train, y_train)

# Predict the model with test data set

y_pred = ModelSVMSig.predict(x_test)
y_pred_prob = ModelSVMSig.predict_proba(x_test)

# Print the model name
    
print('Model Name: ', "SVM - Sigmoid")

# Confusion matrix in sklearn

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# actual values

actual = y_test

# predicted values

predicted = y_pred

# confusion matrix

matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
print('Confusion matrix : \n', matrix)

# outcome values order in sklearn

tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy

C_Report = classification_report(actual,predicted,labels=[1,0])

print('Classification report : \n', C_Report)

# calculating the metrics

sensitivity = round(tp/(tp+fn), 3);
specificity = round(tn/(tn+fp), 3);
accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
balanced_accuracy = round((sensitivity+specificity)/2, 3);
precision = round(tp/(tp+fp), 3);
f1Score = round((2*tp/(2*tp + fp + fn)), 3);

# Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
# A model with a score of +1 is a perfect model and -1 is a poor model

from math import sqrt

mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

print('Accuracy :', round(accuracy*100, 2),'%')
print('Precision :', round(precision*100, 2),'%')
print('Recall :', round(sensitivity*100,2), '%')
print('F1 Score :', f1Score)
print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
print('MCC :', MCC)

# Area under ROC curve 

from sklearn.metrics import roc_curve, roc_auc_score

print('roc_auc_score:', round(roc_auc_score(y_test, y_pred), 3))

# ROC Curve

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, y_pred)
fpr, tpr, thresholds = roc_curve(y_test,ModelSVMSig.predict_proba(x_test)[:,1])
plt.figure()
# plt.plot
plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show() 
print('-----------------------------------------------------------------------------------------------------')
#---

new_row = {'Model Name' : "SVM - Sigmoid",
            'True_Positive' : tp, 
            'False_Negative' : fn, 
            'False_Positive' : fp,
            'True_Negative' : tn,
            'Accuracy' : accuracy,
            'Precision' : precision,
            'Recall' : sensitivity,
            'F1 Score' : f1Score,
            'Specificity' : specificity,
            'MCC':MCC,
            'ROC_AUC_Score':roc_auc_score(actual, predicted),
            'Balanced Accuracy':balanced_accuracy}
EMResults1 = EMResults1.append(new_row, ignore_index=True)
#-----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  SVM - Sigmoid
# Confusion matrix :
#  [[46 51]
#  [41 69]]
# Outcome values :
#  46 51 41 69
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.53      0.47      0.50        97
#            0       0.57      0.63      0.60       110
#
#     accuracy                           0.56       207
#    macro avg       0.55      0.55      0.55       207
# weighted avg       0.55      0.56      0.55       207
#
# Accuracy : 55.6 %
# Precision : 52.9 %
# Recall : 47.4 %
# F1 Score : 0.5
# Specificity or True Negative Rate : 62.7 %
# Balanced Accuracy : 55.0 %
# MCC : 0.103
# roc_auc_score: 0.551
# -----------------------------------------------------------------------------------------------------

# %%
EMResults1
# Out:
#           Model Name True_Positive False_Negative False_Positive  \
# 0       SVM - Linear            89              8             25
# 1  SVM - Polynominal            85             12             20
# 2     SVM - Gaussian            88              9             25
# 3      SVM - Sigmoid            46             51             41
#
#   True_Negative  Accuracy  Precision  Recall  F1 Score  Specificity    MCC  \
# 0            85     0.841      0.781   0.918     0.844        0.773  0.692
# 1            90     0.845      0.810   0.876     0.842        0.818  0.693
# 2            85     0.836      0.779   0.907     0.838        0.773  0.681
# 3            69     0.556      0.529   0.474     0.500        0.627  0.103
#
#    ROC_AUC_Score  Balanced Accuracy
# 0       0.845127              0.846
# 1       0.847235              0.847
# 2       0.839972              0.840
# 3       0.550750              0.550

# %% [markdown]
# # Comparing the algorithms

# %%
Result = pd.read_csv(r"C:\Users\Dlc\Videos\InternDocs\EMResults.csv")
Result
# Out:
# Empty DataFrame
# Columns: [Model Name, True_Positive, False_Negative, False_Positive, True_Negative, Accuracy, Precision, Recall, F1 Score, Specificity, MCC, ROC_AUC_Score, Balanced Accuracy]
# Index: []

# %%
# Build the Calssification models and compare the results

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# Create objects of classification algorithm with default hyper-parameters

ModelLR = LogisticRegression()
ModelDC = DecisionTreeClassifier()
ModelRF = RandomForestClassifier()
ModelET = ExtraTreesClassifier()
ModelKNN = KNeighborsClassifier(n_neighbors=3)
ModelSVM = SVC(kernel='poly', random_state = 42, class_weight='balanced', probability=True)
ModelGNB = GaussianNB()

# Evalution matrix for all the algorithms

MM = [ModelLR, ModelDC, ModelRF, ModelET, ModelKNN, ModelSVM, ModelGNB]
for models in MM:
    
    # Fit the model
    
    models.fit(x_train, y_train)
    
    # Prediction
    
    y_pred = models.predict(x_test)
    y_pred_prob = models.predict_proba(x_test)
    
    # Print the model name
    
    print('Model Name: ', models)
    
    # confusion matrix in sklearn

    from sklearn.metrics import confusion_matrix
    from sklearn.metrics import classification_report

    # actual values

    actual = y_test

    # predicted values

    predicted = y_pred

    # confusion matrix

    matrix = confusion_matrix(actual,predicted, labels=[1,0],sample_weight=None, normalize=None)
    print('Confusion matrix : \n', matrix)

    # outcome values order in sklearn

    tp, fn, fp, tn = confusion_matrix(actual,predicted,labels=[1,0]).reshape(-1)
    print('Outcome values : \n', tp, fn, fp, tn)

    # classification report for precision, recall f1-score and accuracy

    C_Report = classification_report(actual,predicted,labels=[1,0])

    print('Classification report : \n', C_Report)

    # calculating the metrics

    sensitivity = round(tp/(tp+fn), 3);
    specificity = round(tn/(tn+fp), 3);
    accuracy = round((tp+tn)/(tp+fp+tn+fn), 3);
    balanced_accuracy = round((sensitivity+specificity)/2, 3);
    
    precision = round(tp/(tp+fp), 3);
    f1Score = round((2*tp/(2*tp + fp + fn)), 3);

    # Matthews Correlation Coefficient (MCC). Range of values of MCC lie between -1 to +1. 
    # A model with a score of +1 is a perfect model and -1 is a poor model

    from math import sqrt

    mx = (tp+fp) * (tp+fn) * (tn+fp) * (tn+fn)
    MCC = round(((tp * tn) - (fp * fn)) / sqrt(mx), 3)

    print('Accuracy :', round(accuracy*100, 2),'%')
    print('Precision :', round(precision*100, 2),'%')
    print('Recall :', round(sensitivity*100,2), '%')
    print('F1 Score :', f1Score)
    print('Specificity or True Negative Rate :', round(specificity*100,2), '%'  )
    print('Balanced Accuracy :', round(balanced_accuracy*100, 2),'%')
    print('MCC :', MCC)

    # Area under ROC curve 

    from sklearn.metrics import roc_curve, roc_auc_score

    print('roc_auc_score:', round(roc_auc_score(actual, predicted), 3))
    
    # ROC Curve
    
    from sklearn.metrics import roc_auc_score
    from sklearn.metrics import roc_curve
    logit_roc_auc = roc_auc_score(actual, predicted)
    fpr, tpr, thresholds = roc_curve(actual, models.predict_proba(x_test)[:,1])
    plt.figure()
    # plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
    plt.plot(fpr, tpr, label= 'Classification Model' % logit_roc_auc)
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic')
    plt.legend(loc="lower right")
    plt.savefig('Log_ROC')
    plt.show()
    print('-----------------------------------------------------------------------------------------------------')
    #----------------------------------------------------------------------------------------------------------
    new_row = {'Model Name' : models,
               'True_Positive' : tp, 
               'False_Negative' : fn, 
               'False_Positive' : fp,
               'True_Negative' : tn,
               'Accuracy' : accuracy,
               'Precision' : precision,
               'Recall' : sensitivity,
               'F1 Score' : f1Score,
               'Specificity' : specificity,
               'MCC':MCC,
               'ROC_AUC_Score':roc_auc_score(actual, predicted),
               'Balanced Accuracy':balanced_accuracy}
    Result = Result.append(new_row, ignore_index=True)
    #----------------------------------------------------------------------------------------------------------
# Out:
# Model Name:  LogisticRegression()
# Confusion matrix :
#  [[87 10]
#  [22 88]]
# Outcome values :
#  87 10 22 88
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.80      0.90      0.84        97
#            0       0.90      0.80      0.85       110
#
#     accuracy                           0.85       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.85      0.85      0.85       207
#
# Accuracy : 84.5 %
# Precision : 79.8 %
# Recall : 89.7 %
# F1 Score : 0.845
# Specificity or True Negative Rate : 80.0 %
# Balanced Accuracy : 84.8 %
# MCC : 0.697
# roc_auc_score: 0.848
# -----------------------------------------------------------------------------------------------------
# Model Name:  DecisionTreeClassifier()
# Confusion matrix :
#  [[81 16]
#  [14 96]]
# Outcome values :
#  81 16 14 96
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.85      0.84      0.84        97
#            0       0.86      0.87      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.85      0.85       207
# weighted avg       0.86      0.86      0.85       207
#
# Accuracy : 85.5 %
# Precision : 85.3 %
# Recall : 83.5 %
# F1 Score : 0.844
# Specificity or True Negative Rate : 87.3 %
# Balanced Accuracy : 85.4 %
# MCC : 0.709
# roc_auc_score: 0.854
# -----------------------------------------------------------------------------------------------------
# Model Name:  RandomForestClassifier()
# Confusion matrix :
#  [[85 12]
#  [13 97]]
# Outcome values :
#  85 12 13 97
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.87      0.88      0.87        97
#            0       0.89      0.88      0.89       110
#
#     accuracy                           0.88       207
#    macro avg       0.88      0.88      0.88       207
# weighted avg       0.88      0.88      0.88       207
#
# Accuracy : 87.9 %
# Precision : 86.7 %
# Recall : 87.6 %
# F1 Score : 0.872
# Specificity or True Negative Rate : 88.2 %
# Balanced Accuracy : 87.9 %
# MCC : 0.758
# roc_auc_score: 0.879
# -----------------------------------------------------------------------------------------------------
# Model Name:  ExtraTreesClassifier()
# Confusion matrix :
#  [[82 15]
#  [17 93]]
# Outcome values :
#  82 15 17 93
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.83      0.85      0.84        97
#            0       0.86      0.85      0.85       110
#
#     accuracy                           0.85       207
#    macro avg       0.84      0.85      0.84       207
# weighted avg       0.85      0.85      0.85       207
#
# Accuracy : 84.5 %
# Precision : 82.8 %
# Recall : 84.5 %
# F1 Score : 0.837
# Specificity or True Negative Rate : 84.5 %
# Balanced Accuracy : 84.5 %
# MCC : 0.69
# roc_auc_score: 0.845
# -----------------------------------------------------------------------------------------------------
# Model Name:  KNeighborsClassifier(n_neighbors=3)
# Confusion matrix :
#  [[83 14]
#  [12 98]]
# Outcome values :
#  83 14 12 98
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.87      0.86      0.86        97
#            0       0.88      0.89      0.88       110
#
#     accuracy                           0.87       207
#    macro avg       0.87      0.87      0.87       207
# weighted avg       0.87      0.87      0.87       207
#
# Accuracy : 87.4 %
# Precision : 87.4 %
# Recall : 85.6 %
# F1 Score : 0.865
# Specificity or True Negative Rate : 89.1 %
# Balanced Accuracy : 87.4 %
# MCC : 0.748
# roc_auc_score: 0.873
# -----------------------------------------------------------------------------------------------------
# Model Name:  SVC(class_weight='balanced', kernel='poly', probability=True, random_state=42)
# Confusion matrix :
#  [[85 12]
#  [18 92]]
# Outcome values :
#  85 12 18 92
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.83      0.88      0.85        97
#            0       0.88      0.84      0.86       110
#
#     accuracy                           0.86       207
#    macro avg       0.85      0.86      0.85       207
# weighted avg       0.86      0.86      0.86       207
#
# Accuracy : 85.5 %
# Precision : 82.5 %
# Recall : 87.6 %
# F1 Score : 0.85
# Specificity or True Negative Rate : 83.6 %
# Balanced Accuracy : 85.6 %
# MCC : 0.711
# roc_auc_score: 0.856
# -----------------------------------------------------------------------------------------------------
# Model Name:  GaussianNB()
# Confusion matrix :
#  [[67 30]
#  [11 99]]
# Outcome values :
#  67 30 11 99
# Classification report :
#                precision    recall  f1-score   support
#
#            1       0.86      0.69      0.77        97
#            0       0.77      0.90      0.83       110
#
#     accuracy                           0.80       207
#    macro avg       0.81      0.80      0.80       207
# weighted avg       0.81      0.80      0.80       207
#
# Accuracy : 80.2 %
# Precision : 85.9 %
# Recall : 69.1 %
# F1 Score : 0.766
# Specificity or True Negative Rate : 90.0 %
# Balanced Accuracy : 79.6 %
# MCC : 0.608
# roc_auc_score: 0.795
# -----------------------------------------------------------------------------------------------------

# %%
#Result with comparing all the agorithms

Result.head(10)
# Out:
#                                           Model Name True_Positive  \
# 0                               LogisticRegression()            87
# 1                           DecisionTreeClassifier()            81
# 2  (DecisionTreeClassifier(max_features='auto', r...            85
# 3  (ExtraTreeClassifier(random_state=2117698336),...            82
# 4                KNeighborsClassifier(n_neighbors=3)            83
# 5  SVC(class_weight='balanced', kernel='poly', pr...            85
# 6                                       GaussianNB()            67
#
#   False_Negative False_Positive True_Negative  Accuracy  Precision  Recall  \
# 0             10             22            88     0.845      0.798   0.897
# 1             16             14            96     0.855      0.853   0.835
# 2             12             13            97     0.879      0.867   0.876
# 3             15             17            93     0.845      0.828   0.845
# 4             14             12            98     0.874      0.874   0.856
# 5             12             18            92     0.855      0.825   0.876
# 6             30             11            99     0.802      0.859   0.691
#
#    F1 Score  Specificity    MCC  ROC_AUC_Score  Balanced Accuracy
# 0     0.845        0.800  0.697       0.848454              0.848
# 1     0.844        0.873  0.709       0.853889              0.854
# 2     0.872        0.882  0.758       0.879053              0.879
# 3     0.837        0.845  0.690       0.845408              0.845
# 4     0.865        0.891  0.748       0.873290              0.874
# 5     0.850        0.836  0.711       0.856326              0.856
# 6     0.766        0.900  0.608       0.795361              0.796

# %%
#predict the values with rf algorithms
y_predKNN=ModelKNN.predict(x_test)

# %%
Results = pd.DataFrame({'Approved_A':y_test, 'Approved_P':y_predKNN})

# Merge two Dataframes on index of both the dataframes

ResultsFinal = Credit_Card_copy.merge(Results, left_index=True, right_index=True)

# Display 5 records randomly

ResultsFinal.sample(5)
# Out:
#      Gender    Age    Debt  Married  BankCustomer               Industry  \
# 671       1  25.83  12.835        1             1  InformationTechnology
# 294       0  16.08   0.335        1             1             Healthcare
# 355       0  16.00   0.165        1             1        ConsumerStaples
# 518       0  28.17   0.375        1             1              Materials
# 363       1  16.92   0.335        0             0             Financials
#
#     Ethnicity  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 671     White          0.500             0         0            0
# 294    Latino          0.000             0         1            1
# 355     White          1.000             0         1            2
# 518     White          0.585             1         1            4
# 363     White          0.290             0         0            0
#
#      DriversLicense       Citizen  ZipCode  Income  Approved  Approved_A  \
# 671               0       ByBirth        0       2         0           0
# 294               0       ByBirth      160     126         0           0
# 355               1       ByBirth      320       1         0           0
# 518               0       ByBirth       80       0         1           1
# 363               0  ByOtherMeans      200       0         0           0
#
#      Approved_P
# 671           0
# 294           0
# 355           0
# 518           1
# 363           0

# %%
# Display 5 records randomly

ResultsFinal.sample(5)
# Out:
#      Gender    Age    Debt  Married  BankCustomer               Industry  \
# 338       0  33.25   3.000        0             0        ConsumerStaples
# 55        1  23.33  11.625        0             0            Industrials
# 606       1  16.17   0.040        1             1                 Energy
# 674       0  37.33   2.500        1             1  ConsumerDiscretionary
# 356       1  41.17   1.335        1             1            Real Estate
#
#     Ethnicity  YearsEmployed  PriorDefault  Employed  CreditScore  \
# 338     White          2.000             0         0            0
# 55      White          0.835             1         0            0
# 606     White          0.040             0         0            0
# 674     Black          0.210             0         0            0
# 356     White          0.165             0         0            0
#
#      DriversLicense  Citizen  ZipCode  Income  Approved  Approved_A  \
# 338               0  ByBirth      180       0         0           0
# 55                1  ByBirth      160     300         1           1
# 606               0  ByBirth        0       0         1           1
# 674               0  ByBirth      260     246         0           0
# 356               0  ByBirth      168       0         0           0
#
#      Approved_P
# 338           0
# 55            1
# 606           0
# 674           0
# 356           0
